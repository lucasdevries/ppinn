# %%
import os, glob
import pydicom
from datetime import datetime

# %%
ctp_dir = r'L:\basic\divi\CMAJOIE\CLEOPATRA\CTP_MRI_data\Data\CTP_DICOM'
mri_dir = r'L:\basic\divi\CMAJOIE\CLEOPATRA\CTP_MRI_data\Data\MRI_DICOM'
PIDs = ['C'+str(x).zfill(3) for x in range(102,117)]

# %%
def days_hours_minutes(td):
    return td.days, td.seconds//3600, (td.seconds//60)%60, 60*(td.seconds//3600) + (td.seconds//60)%60

for ID in PIDs:
    ctp_folder = os.path.join(ctp_dir, ID)
    mri_folder = os.path.join(mri_dir, ID+'*')
    ctp_file = glob.glob(os.path.join(ctp_folder, '**/*.dcm'), recursive=True)[0]
    mri_file = glob.glob(os.path.join(mri_folder, '**/*.dcm'), recursive=True)[0]

    ctp_ds = pydicom.dcmread(ctp_file)
    mri_ds = pydicom.dcmread(mri_file)
    # print(ID, ctp_ds[0x0008, 0x1010].value, mri_ds[0x0008, 0x1010].value)
    if ID == 'C109':
        print(ID, ctp_ds, mri_ds)


    try:
        time_ctp = datetime.strptime(ctp_ds[0x0008, 0x0031].value, "%H%M%S.%f")
    except:
        time_ctp = datetime.strptime(ctp_ds[0x0008, 0x0031].value, "%H%M%S")
    try:
        time_mri = datetime.strptime(mri_ds[0x0008, 0x0032].value, "%H%M%S.%f")
    except:
        time_mri = datetime.strptime(mri_ds[0x0008, 0x0032].value, "%H%M%S")
    #
    # print(ID, days_hours_minutes(time_mri-time_ctp))
    # print(ID, time_mri.minute -time_ctp)
# Out:
# C109 Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 218
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.12.2.1107.5.1.4.75508.30000019031807445061700537814
# (0002, 0010) Transfer Syntax UID                 UI: JPEG Lossless, Non-Hierarchical, First-Order Prediction (Process 14 [Selection Value 1])
# (0002, 0012) Implementation Class UID            UI: 1.2.276.0.7230010.3.0.3.6.3
# (0002, 0013) Implementation Version Name         SH: 'OFFIS_DCMTK_363'
# (0002, 0016) Source Application Entity Title     AE: 'WF_PROD'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL', 'CT_SOM5 SPI']
# ...

# %%
ds = pydicom.dcmread(r"L:\basic\divi\CMAJOIE\CLEOPATRA\CTP_MRI_data\Data\CTP_DICOM\C113\00004_VPCT___Brein_Perfusie__5.0__Hr36\00001_1.3.12.2.1107.5.1.4.75508.30000020021307464436300073696.dcm")

# %%
from shutil import copy
ds
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 218
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.12.2.1107.5.1.4.75508.30000020021307464436300073696
# (0002, 0010) Transfer Syntax UID                 UI: JPEG Lossless, Non-Hierarchical, First-Order Prediction (Process 14 [Selection Value 1])
# (0002, 0012) Implementation Class UID            UI: 1.2.276.0.7230010.3.0.3.6.3
# (0002, 0013) Implementation Version Name         SH: 'OFFIS_DCMTK_363'
# (0002, 0016) Source Application Entity Title     AE: 'WF_PROD'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL', 'CT_SOM5 SPI']
# ...

# %%
runs = ['1efpznt7',
'xnk79q5i',
'bjmcrv26',
'qc2sd8li',
'xasjoeii',
'dnt6xjyy',
'pjxlhsyk',
'dt5f2f74',
'133kq72a',
'6gzbj6en',
'tdsgaiqe',
'85l2cera',
'7dsz1v64',
'rcxr5462',
'k8fjmp8b',
'yb7pxwtg',
'2kfnqumy',
'ghptxiui',
'hpbq2zad',
'k0kqw8tq',
'lbhmpd03',
'4yyd7tb4',
'3mfi3ccl',
'fp8wu5cu',
'ggm922bn']

for i in runs:
    file = glob.glob(rf"C:\Users\lucasdevries\surfdrive\Projects\ppinn\wandb\*{i}\files\ppinn_results_*.pickle")[0]
    filename = file.split(os.sep)[-1]
    path = r"C:\Users\lucasdevries\surfdrive\Projects\ppinn\data\ppinn_results"
    print(file)
    copy(file, os.path.join(path, filename))
# Out:
# C:\Users\lucasdevries\surfdrive\Projects\ppinn\wandb\run-20221027_093005-1efpznt7\files\ppinn_results_cbv_5_sd_4_undersample_0.pickle
# C:\Users\lucasdevries\surfdrive\Projects\ppinn\wandb\run-20221027_075725-xnk79q5i\files\ppinn_results_cbv_5_sd_3_undersample_0.pickle
# C:\Users\lucasdevries\surfdrive\Projects\ppinn\wandb\run-20221027_062452-bjmcrv26\files\ppinn_results_cbv_5_sd_2_undersample_0.pickle
# C:\Users\lucasdevries\surfdrive\Projects\ppinn\wandb\run-20221027_044224-qc2sd8li\files\ppinn_results_cbv_5_sd_1_undersample_0.pickle
# C:\Users\lucasdevries\surfdrive\Projects\ppinn\wandb\run-20221027_030120-xasjoeii\files\ppinn_results_cbv_5_sd_5_undersample_0.pickle
# C:\Users\lucasdevries\surfdrive\Projects\ppinn\wandb\run-20221027_012437-dnt6xjyy\files\ppinn_results_cbv_4_sd_4_undersample_0.pickle
# C:\Users\lucasdevries\surfdrive\Projects\ppinn\wandb\run-20221026_235232-pjxlhsyk\files\ppinn_results_cbv_4_sd_3_undersample_0.pickle
# ...
